# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

# %%
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
from tqdm.notebook import tqdm
from PIL import Image
import os

# %%
from torchinfo import summary

# %%
## parameters
### 五张图片一组
step=5

# %% [markdown]
# ### read images

# %%
## path = r'C:\Users\liuya\Downloads\3d_printing_research\clipped_samples_otsu'
path = r'C:\Users\liuya\Downloads\3d_printing_research\clipped_samples'
image_list = os.listdir(path)

# %%
full_path = os.path.join(path, image_list[350])
np.array(Image.open(full_path).convert('RGB')).shape
# Out:
# (250, 730, 3)

# %%
image_ls = []

for i in tqdm(image_list):
    full_path = os.path.join(path, i)
    img = Image.open(full_path).convert('L')
    img_array = np.asarray(img)
    image_ls.append(img_array)
# Out:
#   0%|          | 0/4046 [00:00<?, ?it/s]

# %%
### normalize
data_input = np.array(image_ls)
### np.divide((data_input-np.min(data_input)), (np.max(data_input)-np.min(data_input)))

# %%
data_input = np.divide((data_input-np.min(data_input)), (np.max(data_input)-np.min(data_input)))

# %%
data_input = torch.tensor(data_input[:,None,:,:], dtype=torch.float32)

# %%
data_input.shape
# Out:
# torch.Size([4046, 1, 250, 730])

# %% [markdown]
# ### build the model

# %%
class Conv_NN_encoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv2d1 = nn.Conv2d(1, 16, kernel_size=(10,30))
        self.maxpool2d1 = nn.MaxPool2d((3,9), return_indices=True)
        self.conv2d2 = nn.Conv2d(16, 8, kernel_size=(10,30))
        self.maxpool2d2 = nn.MaxPool2d((3,9), return_indices=True)
        self.flatten = nn.Flatten()
        self.linear1 = nn.Linear(in_features=920, out_features=128)
        
    def forward(self, x):
        batch_size = x.shape[0]
        n_tau = x.shape[2]
        ## 1 means 1 channel, multiply sample size with tau to create this many of 1*W vectors
        ## x = x.view((-1, 1, x.shape[3], x.shape[4]))
        output = F.relu(self.conv2d1(x))
        output, indices1 = self.maxpool2d1(output)
        output = F.relu(self.conv2d2(output))
        output, indices2 = self.maxpool2d2(output)
        output = self.flatten(output)
        output = self.linear1(output)
        #back to the previous dimension (sample_size, tau)
        #output = output.view((batch_size, n_tau, -1))
        return output, indices1, indices2

# %%
class Conv_NN_decoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear1 = nn.Linear(128, 920)
        self.maxunpool2d1 = nn.MaxUnpool2d((3,9))
        ## self.conv2d1 = nn.Conv2d(8, 16, kernel_size=(10,30), padding=(9,29))
        self.conv2d1 = nn.ConvTranspose2d(8, 16, kernel_size=(10,30))
        self.maxunpool2d2 = nn.MaxUnpool2d((3,9))
        ## self.conv2d2 = nn.Conv2d(16, 1, kernel_size=(10,30), padding=(9,29))
        self.conv2d2 = nn.ConvTranspose2d(16, 1, kernel_size=(10,30))
        #self.pad = nn.ConstantPad2d((9,9,58,0), 0)

        
    def forward(self, x, indices1, indices2):
        ## x = x.contiguous().view((-1, x.shape[2]))
        output = self.linear1(x)
        output = output.view((output.shape[0], 8, -1, 5))
        output = self.maxunpool2d1(output, indices2, output_size=torch.Size([output.shape[0], 8, 71, 48]))
        output = self.conv2d1(output)
        output = self.maxunpool2d2(output, indices1, output_size=torch.Size([output.shape[0], 16, 241, 701]))
        output = self.conv2d2(output)
        #output = self.pad(output)
        #back to original size
        #output = output.view((-1, 1, 5, output.shape[2], output.shape[3]))
        return output

# %%
class net(nn.Module):
    def __init__(self, *args):
        super().__init__()
        self.Conv_NN_encoder = args[0]
        self.Conv_NN_decoder = args[1]
    
    def forward(self, x):
        output, indc1, indc2 = self.Conv_NN_encoder(x)
        output = self.Conv_NN_decoder(output, indc1, indc2)
        return output

# %%
model = net(Conv_NN_encoder(), Conv_NN_decoder())

# %%
summary(model,input_size=(10,1,250,730))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# net                                      --                        --
# ├─Conv_NN_encoder: 1-1                   [10, 128]                 --
# │    └─Conv2d: 2-1                       [10, 16, 241, 701]        4,816
# │    └─MaxPool2d: 2-2                    [10, 16, 80, 77]          --
# │    └─Conv2d: 2-3                       [10, 8, 71, 48]           38,408
# │    └─MaxPool2d: 2-4                    [10, 8, 23, 5]            --
# │    └─Flatten: 2-5                      [10, 920]                 --
# │    └─Linear: 2-6                       [10, 128]                 117,888
# ├─Conv_NN_decoder: 1-2                   [10, 1, 250, 730]         --
# │    └─Linear: 2-7                       [10, 920]                 118,680
# │    └─MaxUnpool2d: 2-8                  [10, 8, 71, 48]           --
# │    └─ConvTranspose2d: 2-9              [10, 16, 80, 77]          38,416
# │    └─MaxUnpool2d: 2-10                 [10, 16, 241, 701]        --
# │    └─ConvTranspose2d: 2-11             [10, 1, 250, 730]         4,801
# ==========================================================================================
# Total params: 323,009
# Trainable params: 323,009
# Non-trainable params: 0
# Total mult-adds (G): 20.58
# ==========================================================================================
# Input size (MB): 7.30
# Forward/backward pass size (MB): 240.99
# Params size (MB): 1.29
# Estimated Total Size (MB): 249.59
# ==========================================================================================

# %% [markdown]
# ### train the model

# %%
def train(model, device, train_loader, optimizer, epoch):
    
    model.train() #trian model
    for batch_idx, data in enumerate(train_loader):
        data = data.to(device)
        optimizer.zero_grad()
        output = model(data)

        ##calculate loss
        loss = 0
        for i in range(data.shape[0]):
            loss += F.mse_loss(output[i], data[i], reduction='sum')
        loss /= data.shape[0]
        #loss = F.mse_loss(output, data)
        loss.backward()
        optimizer.step()
        # print result every 10 batch
        if batch_idx % 10 == 0:
            print('Train Epoch: {} ... Batch: {} ... Loss: {:.8f}'.format(epoch, batch_idx, loss))

# %%
def test(model, device, test_loader):
    model.eval() #evaluate model
    test_loss = 0
    with torch.no_grad():
        for data in test_loader:
            data = data.to(device)
            output = model(data)
            #calculate sum loss
            test_loss += F.mse_loss(output, data, reduction='sum').item()
    
        test_loss /= len(test_loader.dataset)
        print('------------------- Test set: Average loss: {:.4f} ... Samples: {}'.format(test_loss, len(test_loader.dataset)))

# %% [markdown]
# ### train and test split

# %%
train_window_, val_window_ = train_test_split(data_input, test_size=0.2, random_state=2022)

# %%
train_loader = torch.utils.data.DataLoader(train_window_, batch_size=16,shuffle=True)
test_loader = torch.utils.data.DataLoader(val_window_, batch_size=16,shuffle=False)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
model = model.to(device)

# %%
optimizer = optim.Adam(model.parameters(), lr=0.000000001)

# %%
epochs = 5

# %%
for epoch in range(1, epochs + 1):
    train(model, device, train_loader, optimizer, epoch)
    test(model, device, test_loader)
# Out:
# Train Epoch: 1 ... Batch: 0 ... Loss: 2073.71020508
# Train Epoch: 1 ... Batch: 10 ... Loss: 2159.55957031
# Train Epoch: 1 ... Batch: 20 ... Loss: 2168.56494141
# Train Epoch: 1 ... Batch: 30 ... Loss: 1985.68896484
# Train Epoch: 1 ... Batch: 40 ... Loss: 1967.27819824
# Train Epoch: 1 ... Batch: 50 ... Loss: 2015.08251953
# Train Epoch: 1 ... Batch: 60 ... Loss: 2068.00488281
# Train Epoch: 1 ... Batch: 70 ... Loss: 2153.30834961
# Train Epoch: 1 ... Batch: 80 ... Loss: 1931.04284668
# Train Epoch: 1 ... Batch: 90 ... Loss: 1911.37756348
# Train Epoch: 1 ... Batch: 100 ... Loss: 2018.67004395
# Train Epoch: 1 ... Batch: 110 ... Loss: 1887.96435547
# Train Epoch: 1 ... Batch: 120 ... Loss: 2038.35485840
# Train Epoch: 1 ... Batch: 130 ... Loss: 2293.45385742
# Train Epoch: 1 ... Batch: 140 ... Loss: 2098.67822266
# Train Epoch: 1 ... Batch: 150 ... Loss: 2057.14721680
# Train Epoch: 1 ... Batch: 160 ... Loss: 2078.20654297
# Train Epoch: 1 ... Batch: 170 ... Loss: 2262.90893555
# Train Epoch: 1 ... Batch: 180 ... Loss: 1976.63940430
# Train Epoch: 1 ... Batch: 190 ... Loss: 1990.58264160
# Train Epoch: 1 ... Batch: 200 ... Loss: 2180.15917969
# ------------------- Test set: Average loss: 2074.6996 ... Samples: 810
# Train Epoch: 2 ... Batch: 0 ... Loss: 2049.45410156
# Train Epoch: 2 ... Batch: 10 ... Loss: 2037.05749512
# Train Epoch: 2 ... Batch: 20 ... Loss: 2151.75878906
# Train Epoch: 2 ... Batch: 30 ... Loss: 2001.78198242
# Train Epoch: 2 ... Batch: 40 ... Loss: 1954.50842285
# Train Epoch: 2 ... Batch: 50 ... Loss: 1988.27441406
# Train Epoch: 2 ... Batch: 60 ... Loss: 2152.20288086
# Train Epoch: 2 ... Batch: 70 ... Loss: 2319.15087891
# Train Epoch: 2 ... Batch: 80 ... Loss: 2022.22912598
# Train Epoch: 2 ... Batch: 90 ... Loss: 1985.07922363
# Train Epoch: 2 ... Batch: 100 ... Loss: 2036.41186523
# Train Epoch: 2 ... Batch: 110 ... Loss: 2135.19995117
# Train Epoch: 2 ... Batch: 120 ... Loss: 2023.96984863
# Train Epoch: 2 ... Batch: 130 ... Loss: 2163.51342773
# Train Epoch: 2 ... Batch: 140 ... Loss: 1925.99145508
# Train Epoch: 2 ... Batch: 150 ... Loss: 2125.17675781
# Train Epoch: 2 ... Batch: 160 ... Loss: 2100.79150391
# Train Epoch: 2 ... Batch: 170 ... Loss: 1993.06518555
# Train Epoch: 2 ... Batch: 180 ... Loss: 2074.53369141
# Train Epoch: 2 ... Batch: 190 ... Loss: 2066.68505859
# Train Epoch: 2 ... Batch: 200 ... Loss: 2006.72241211
# ------------------- Test set: Average loss: 2074.7227 ... Samples: 810
# Train Epoch: 3 ... Batch: 0 ... Loss: 1937.55786133
# Train Epoch: 3 ... Batch: 10 ... Loss: 2086.72509766
# Train Epoch: 3 ... Batch: 20 ... Loss: 2200.28076172
# Train Epoch: 3 ... Batch: 30 ... Loss: 2062.33081055
# Train Epoch: 3 ... Batch: 40 ... Loss: 2157.89477539
# Train Epoch: 3 ... Batch: 50 ... Loss: 1908.18579102
# Train Epoch: 3 ... Batch: 60 ... Loss: 2102.37841797
# Train Epoch: 3 ... Batch: 70 ... Loss: 2034.15588379
# Train Epoch: 3 ... Batch: 80 ... Loss: 2041.55151367
# Train Epoch: 3 ... Batch: 90 ... Loss: 2055.48046875
# Train Epoch: 3 ... Batch: 100 ... Loss: 2126.18481445
# Train Epoch: 3 ... Batch: 110 ... Loss: 1948.35559082
# Train Epoch: 3 ... Batch: 120 ... Loss: 2100.24218750
# Train Epoch: 3 ... Batch: 130 ... Loss: 2286.55517578
# Train Epoch: 3 ... Batch: 140 ... Loss: 1968.13122559
# Train Epoch: 3 ... Batch: 150 ... Loss: 2016.53015137
# Train Epoch: 3 ... Batch: 160 ... Loss: 1974.44531250
# Train Epoch: 3 ... Batch: 170 ... Loss: 2090.81396484
# Train Epoch: 3 ... Batch: 180 ... Loss: 2302.22509766
# Train Epoch: 3 ... Batch: 190 ... Loss: 1991.18530273
# Train Epoch: 3 ... Batch: 200 ... Loss: 2093.53344727
# ------------------- Test set: Average loss: 2074.7521 ... Samples: 810
# Train Epoch: 4 ... Batch: 0 ... Loss: 2131.99658203
# Train Epoch: 4 ... Batch: 10 ... Loss: 2080.08178711
# Train Epoch: 4 ... Batch: 20 ... Loss: 2053.07055664
# Train Epoch: 4 ... Batch: 30 ... Loss: 1968.24609375
# Train Epoch: 4 ... Batch: 40 ... Loss: 2126.19897461
# Train Epoch: 4 ... Batch: 50 ... Loss: 2091.09350586
# Train Epoch: 4 ... Batch: 60 ... Loss: 1857.85510254
# Train Epoch: 4 ... Batch: 70 ... Loss: 1947.43432617
# Train Epoch: 4 ... Batch: 80 ... Loss: 2108.12817383
# Train Epoch: 4 ... Batch: 90 ... Loss: 2174.63818359
# Train Epoch: 4 ... Batch: 100 ... Loss: 2038.15197754
# Train Epoch: 4 ... Batch: 110 ... Loss: 2169.35937500
# Train Epoch: 4 ... Batch: 120 ... Loss: 2136.34570312
# Train Epoch: 4 ... Batch: 130 ... Loss: 1984.60534668
# Train Epoch: 4 ... Batch: 140 ... Loss: 2042.10949707
# Train Epoch: 4 ... Batch: 150 ... Loss: 2131.17944336
# Train Epoch: 4 ... Batch: 160 ... Loss: 2014.29711914
# Train Epoch: 4 ... Batch: 170 ... Loss: 2157.85034180
# Train Epoch: 4 ... Batch: 180 ... Loss: 2024.91552734
# Train Epoch: 4 ... Batch: 190 ... Loss: 2006.85620117
# Train Epoch: 4 ... Batch: 200 ... Loss: 2139.95434570
# ------------------- Test set: Average loss: 2074.7451 ... Samples: 810
# Train Epoch: 5 ... Batch: 0 ... Loss: 2026.43676758
# Train Epoch: 5 ... Batch: 10 ... Loss: 2030.11755371
# Train Epoch: 5 ... Batch: 20 ... Loss: 1876.66674805
# Train Epoch: 5 ... Batch: 30 ... Loss: 2153.38427734
# Train Epoch: 5 ... Batch: 40 ... Loss: 2097.23193359
# Train Epoch: 5 ... Batch: 50 ... Loss: 2032.16125488
# Train Epoch: 5 ... Batch: 60 ... Loss: 2046.35913086
# Train Epoch: 5 ... Batch: 70 ... Loss: 2140.47216797
# Train Epoch: 5 ... Batch: 80 ... Loss: 2135.36816406
# Train Epoch: 5 ... Batch: 90 ... Loss: 2078.95361328
# Train Epoch: 5 ... Batch: 100 ... Loss: 2008.56823730
# Train Epoch: 5 ... Batch: 110 ... Loss: 2014.59582520
# Train Epoch: 5 ... Batch: 120 ... Loss: 2067.21606445
# Train Epoch: 5 ... Batch: 130 ... Loss: 2043.27490234
# Train Epoch: 5 ... Batch: 140 ... Loss: 2076.47314453
# Train Epoch: 5 ... Batch: 150 ... Loss: 2159.44726562
# Train Epoch: 5 ... Batch: 160 ... Loss: 2056.16333008
# Train Epoch: 5 ... Batch: 170 ... Loss: 2067.61328125
# Train Epoch: 5 ... Batch: 180 ... Loss: 1922.45910645
# Train Epoch: 5 ... Batch: 190 ... Loss: 2014.13488770
# Train Epoch: 5 ... Batch: 200 ... Loss: 2081.01391602
# ------------------- Test set: Average loss: 2074.7441 ... Samples: 810

# %%
## old 3846104064
## new 389223789
## new2 5500
## new3 2000

# %% [markdown]
# ### test the result

# %%
data_input[0].shape
# Out:
# torch.Size([1, 250, 730])

# %%
model.eval() #evaluate model
with torch.no_grad():
    data = data_input[350]
    data = data[None,:,:,:]
    data = data.to(device)
    output = model(data)
    output = output.cpu()

# %%
## cut the image
original = data_input[350,0].numpy()*255
Image.fromarray(original.astype('uint8'), 'L')
# Out:
# <PIL.Image.Image image mode=L size=730x250 at 0x19EC0D62D60>

# %%
predict = output[0,0].numpy()*255
Image.fromarray(predict.astype('uint8'), 'L')
# Out:
# <PIL.Image.Image image mode=L size=730x250 at 0x19ECACAD0D0>

# %%
## Image.fromarray(output[0,0].numpy().astype('uint8'), 'L')
